# %%
import pandas as pd

# %%
data = pd.read_csv('test1.csv')

# %%
data.head()
# Out:
#    area               detail     dinner_price  \
# 0   NaN  4.8,4.8,4.8,4.0,4.0  ￥20,000～￥29,999
# 1   NaN  4.8,4.8,4.8,4.7,4.8              NaN
# 2   NaN  5.0,5.0,5.0,5.0,5.0  ￥20,000～￥29,999
# 3   NaN  5.0,4.8,4.7,5.0,4.0  ￥20,000～￥29,999
# 4   NaN  4.9,4.5,4.2,4.0,4.5  ￥20,000～￥29,999
#
#                                        dinner_review  \
# 0  \n          再  訪(19.11月)　都寿司の頃から通って、一貫して一番好きだっ...
# 1  \n          8月に続き、またお邪魔しました。大将のお人柄を反映して、店内には、柔...
# 2                                                NaN
# 3  \n          食べログで全国No1(2019/9現在)に輝く、最高のお店、なかなか...
# 4  \n        粋な大将と至高の江戸前鮨水天宮前駅４番出口（ロイヤルパークホテル）から徒...
#
#                                                 link      lunch_price  \
# 0  https://tabelog.com/tokyo/A1302/A130204/13018162/  ￥20,000～￥29,999
# 1  https://tabelog.com/tokyo/A1301/A130102/13219857/  ￥20,000～￥29,999
# 2  https://tabelog.com/tokyo/A1308/A130802/13015251/  ￥10,000～￥14,999
# 3  https://tabelog.com/tokyo/A1302/A130204/13018162/  ￥20,000～￥29,999
# ...

# %%
data.drop(['link', 'area'], axis = 1)
# Out:
#                   detail     dinner_price  \
# 0    4.8,4.8,4.8,4.0,4.0  ￥20,000～￥29,999
# 1    4.8,4.8,4.8,4.7,4.8              NaN
# 2    5.0,5.0,5.0,5.0,5.0  ￥20,000～￥29,999
# 3    5.0,4.8,4.7,5.0,4.0  ￥20,000～￥29,999
# 4    4.9,4.5,4.2,4.0,4.5  ￥20,000～￥29,999
# ..                   ...              ...
# 333            -,-,-,-,-  ￥20,000～￥29,999
# 334            -,-,-,-,-  ￥20,000～￥29,999
# 335  4.5,4.3,4.5,4.2,4.0  ￥20,000～￥29,999
# 336  4.5,4.3,4.5,4.2,4.0  ￥20,000～￥29,999
# 337  4.4,4.3,4.5,4.2,4.0  ￥20,000～￥29,999
#
#                                          dinner_review      lunch_price  \
# 0    \n          再  訪(19.11月)　都寿司の頃から通って、一貫して一番好きだっ...  ￥20,000～￥29,999
# 1    \n          8月に続き、またお邪魔しました。大将のお人柄を反映して、店内には、柔...  ￥20,000～￥29,999
# 2                                                  NaN  ￥10,000～￥14,999
# 3    \n          食べログで全国No1(2019/9現在)に輝く、最高のお店、なかなか...  ￥20,000～￥29,999
# 4    \n        粋な大将と至高の江戸前鮨水天宮前駅４番出口（ロイヤルパークホテル）から徒...  ￥20,000～￥29,999
# ...

# %%
c = data[data['store_name'] == '日本橋蛎殻町 すぎた']

# %%
c[c['lunch_review'] != NaN]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-b1f89cf5c5ec> in <module>
# ----> 1 c[c['lunch_review'] != NaN]
#
# NameError: name 'NaN' is not defined
